# %% [markdown]
# # Import Pandas

# %%
import pandas as pd

# %% [markdown]
# # Import data

# %%
names=['Id','Title','Year','Rating','Voting','Duration','Gonre']
data=pd.read_csv('imdb_top_10000.txt',sep='\t',index_col=0,names=names)

# %% [markdown]
# # Explore data

# %% [markdown]
# ### data.head() gives us first five elements

# %%
data.head()

# %% [markdown]
# ### data.head(n) gives first n elements

# %%
data.head(8)
# Out:
#                                      Title  Year  Rating  Voting   Duration  \
# Id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
# tt0109830              Forrest Gump (1994)  1994     8.7  368994  142 mins.
# tt0169547           American Beauty (1999)  1999     8.6  338332  122 mins.
# tt0499549                    Avatar (2009)  2009     8.1  336855  162 mins.
#
#                                       Gonre
# Id
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller
# ...

# %%
data.head(10005)
# Out:
#                                      Title  Year  Rating  Voting   Duration  \
# Id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
# ...                                    ...   ...     ...     ...        ...
# tt0807721                   Meduzot (2007)  2007     7.0    1357   78 mins.
# tt0339642            Daltry Calhoun (2005)  2005     5.2    1357  100 mins.
# tt0060880    The Quiller Memorandum (1966)  1966     6.5    1356  104 mins.
# tt0152836                      Taal (1999)  1999     6.5    1356  179 mins.
# tt0279977            The Navigators (2001)  2001     6.9    1356   96 mins.
#
#                                       Gonre
# Id
# ...

# %% [markdown]
# ### data.tail() gives five elements from last

# %%
data.tail()
# Out:
#                                    Title  Year  Rating  Voting   Duration  \
# Id
# tt0807721                 Meduzot (2007)  2007     7.0    1357   78 mins.
# tt0339642          Daltry Calhoun (2005)  2005     5.2    1357  100 mins.
# tt0060880  The Quiller Memorandum (1966)  1966     6.5    1356  104 mins.
# tt0152836                    Taal (1999)  1999     6.5    1356  179 mins.
# tt0279977          The Navigators (2001)  2001     6.9    1356   96 mins.
#
#                                 Gonre
# Id
# tt0807721                       Drama
# tt0339642  Comedy|Drama|Music|Romance
# tt0060880      Drama|Mystery|Thriller
# tt0152836             Musical|Romance
# tt0279977                Comedy|Drama

# %%
data.tail(8)
# Out:
#                                    Title  Year  Rating  Voting   Duration  \
# Id
# tt0339727               Stateside (2004)  2004     5.8    1358   97 mins.
# tt0218581            Scarlet Diva (2000)  2000     5.2    1358   91 mins.
# tt0118635                  Aprile (1998)  1998     6.7    1358   78 mins.
# tt0807721                 Meduzot (2007)  2007     7.0    1357   78 mins.
# tt0339642          Daltry Calhoun (2005)  2005     5.2    1357  100 mins.
# tt0060880  The Quiller Memorandum (1966)  1966     6.5    1356  104 mins.
# tt0152836                    Taal (1999)  1999     6.5    1356  179 mins.
# tt0279977          The Navigators (2001)  2001     6.9    1356   96 mins.
#
#                                 Gonre
# Id
# tt0339727         Drama|Music|Romance
# tt0218581                       Drama
# tt0118635                      Comedy
# tt0807721                       Drama
# tt0339642  Comedy|Drama|Music|Romance
# tt0060880      Drama|Mystery|Thriller
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     10000 non-null  object
#  1   Year      10000 non-null  int64
#  2   Rating    10000 non-null  float64
#  3   Voting    10000 non-null  int64
#  4   Duration  10000 non-null  object
#  5   Gonre     9999 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 546.9+ KB

# %% [markdown]
# ### data describe only works on int and float

# %%
data.describe()
# Out:
#                Year        Rating         Voting
# count  10000.000000  10000.000000   10000.000000
# mean    1993.472800      6.386070   16604.012800
# std       14.829924      1.189933   34563.459698
# min     1950.000000      1.500000    1356.000000
# 25%     1986.000000      5.700000    2333.750000
# 50%     1998.000000      6.600000    4980.500000
# 75%     2005.000000      7.200000   15277.750000
# max     2011.000000      9.200000  619479.000000

# %%
top_kannada_movies=pd.read_csv('Top kannada movies.csv',index_col=0)

# %%
top_kannada_movies.head(10)
# Out:
#               Const     Created    Modified  Description  \
# Position
# 1         tt3394420  2018-12-29  2018-12-29          NaN
# 2         tt7838252  2018-12-29  2018-12-29          NaN
# 3         tt2358592  2018-12-29  2018-12-29          NaN
# 4         tt4432480  2018-12-29  2018-12-29          NaN
# 5         tt4881362  2018-12-30  2018-12-30          NaN
# 6         tt8602654  2018-12-29  2018-12-29          NaN
# 7         tt3320542  2018-12-29  2018-12-29          NaN
# 8         tt4909506  2018-12-29  2018-12-29          NaN
# 9         tt2330098  2018-12-29  2018-12-29          NaN
# 10        tt0986329  2018-12-29  2018-12-29          NaN
#
#                                                       Title  \
# Position
# 1                                       Ulidavaru Kandanthe
# 2                                          K.G.F: Chapter 1
# 3                                                     Lucia
# 4                                              RangiTaranga
# ...

# %% [markdown]
# # sort data

# %%
top_kannada_movies.sort_values(by='IMDb Rating',ascending=False)
# Out:
#               Const     Created    Modified  Description  \
# Position
# 9         tt2330098  2018-12-29  2018-12-29          NaN
# 21        tt0250745  2018-12-29  2018-12-29          NaN
# 8         tt4909506  2018-12-29  2018-12-29          NaN
# 6         tt8602654  2018-12-29  2018-12-29          NaN
# 18        tt6805436  2018-12-29  2018-12-29          NaN
# 1         tt3394420  2018-12-29  2018-12-29          NaN
# 3         tt2358592  2018-12-29  2018-12-29          NaN
# 4         tt4432480  2018-12-29  2018-12-29          NaN
# 10        tt0986329  2018-12-29  2018-12-29          NaN
# 11        tt6054758  2018-12-29  2018-12-29          NaN
# 19        tt0233270  2018-12-29  2018-12-29          NaN
# 16        tt5471570  2018-12-29  2018-12-29          NaN
# 25        tt7479902  2018-12-29  2018-12-29          NaN
# 22        tt0309764  2018-12-29  2018-12-29          NaN
# 2         tt7838252  2018-12-29  2018-12-29          NaN
# ...

# %%
top_kannada_movies.to_csv('kannada_movies_list',sep=' ',header=True)
